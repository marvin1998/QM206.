# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A=1.0
B=2
C=0
k1=0.15
dt=0.1
t=0
x=[]
yA=[]
yB=[]
yC=[]
while t<100:
    x.append(t)
    yA.append(A)
    yB.append(B)
    yC.append(C)
    dA=-k1*A*dt
    dB=+k1*A*dt
    dC=+k1*A*dt
    A+=dA
    B+=dB
    C+=dC
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.plot(x,yC)
plt.xlabel("t(m)")
plt.ylabel("Concentracion")
plt.title("Cinetica de primer orden")
plt.show()

# %%
datos=(2.52,3.86,9.64,12.52,20.10)
y=(16.7,25.05,54.23,68.79,106.7)
plt.plot(datos,y)

# %%
requests=[]
r=requests.get("http://qm206.1apps.com/bases.txt")
cadena2=r.text
cadena2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-cd4a20c7a99a> in <module>()
#       1 requests=[]
# ----> 2 r=requests.get("http://qm206.1apps.com/bases.txt")
#       3 cadena2=r.text
#       4 cadena2
#
# AttributeError: 'list' object has no attribute 'get'
