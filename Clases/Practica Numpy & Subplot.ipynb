# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4,5,2,3,8])

# %%
x=np.arange(10)
y=np.sin(x)
plt.plot(x,y,"ro-")
plt.xlabel("distancia(m)")
plt.ylabel("densidad(g/ml)")
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot([1,4,2,6]),'ro-.'
plt.xlabel("x1")
plt.subplot(2,2,2)
plt.hist(np.random.randn(1000),color="orange")
plt.subplot(2,2,3)
plt.plot(np.random.rand(10))
plt.xlabel("x3(cm)")
plt.subplot(2,2,4)
plt.plot([1,2,3])
plt.subtitle("Datos Experimentales")
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-2d2a2e9c2295> in <module>()
#       9 plt.subplot(2,2,4)
#      10 plt.plot([1,2,3])
# ---> 11 plt.subtitle("Datos Experimentales")
#      12 plt.show
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'
